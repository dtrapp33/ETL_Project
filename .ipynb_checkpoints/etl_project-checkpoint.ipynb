# %%
import pandas as pd
#!pip install forex_python
from forex_python.converter import CurrencyRates

# %%
boat_data = "boat_data.csv"

# Read the boat data
boat_df = pd.read_csv(boat_data)

# Display the data table for preview
boat_df.head(5)
# Out:
#        Price            Boat Type          Manufacturer                 Type  \
# 0   CHF 3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   EUR 3490  Center console boat     Terhi power boats  new boat from stock
# 2   CHF 3770           Sport Boat    Marine power boats  new boat from stock
# 3  DKK 25900           Sport Boat    Pioner power boats  new boat from stock
# 4   EUR 3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58

# %%
data_df = boat_df[['Price', 'Boat Type', 'Manufacturer', 'Type', 'Year Built', 'Length', 'Width', 'Material', 
                                        'Location', 'Number of views last 7 days']]
data_df
# Out:
#           Price            Boat Type           Manufacturer  \
# 0      CHF 3337          Motor Yacht   Rigiflex power boats
# 1      EUR 3490  Center console boat      Terhi power boats
# 2      CHF 3770           Sport Boat     Marine power boats
# 3     DKK 25900           Sport Boat     Pioner power boats
# 4      EUR 3399         Fishing Boat     Linder power boats
# ...         ...                  ...                    ...
# 9883   CHF 4900           Sport Boat    Sea Ray power boats
# 9884   EUR 4516           Sport Boat                    NaN
# 9885   EUR 4499           Sport Boat  BlueCraft power boats
# 9886   EUR 4300         Pontoon Boat      Whaly power boats
# 9887   CHF 3780         Fishing Boat    DarekCo power boats
#
#                               Type  Year Built  Length  Width       Material  \
# 0              new boat from stock        2017    4.00   1.90            NaN
# 1              new boat from stock        2020    4.00   1.50  Thermoplastic
# 2              new boat from stock           0    3.69   1.42      Aluminium
# 3              new boat from stock        2020    3.00   1.00            NaN
# 4              new boat from stock        2019    3.55   1.46      Aluminium
# ...                            ...         ...     ...    ...            ...
# 9883            Used boat,Unleaded        1987    6.30   2.44            NaN
# 9884           new boat from stock           0    4.17   1.68            GRP
# 9885  new boat from stock,Unleaded        2020    4.40   1.80            GRP
# 9886           new boat from stock        2018    4.37   1.89            NaN
# 9887           new boat from stock        2019    3.60   1.60            GRP
#
#                                         Location  Number of views last 7 days
# 0         Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                       Germany Â» BÃ¶nningstedt                           75
# 2     Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                           Denmark Â» Svendborg                           64
# 4                  Germany Â» Bayern Â» MÃ¼nchen                           58
# ...                                          ...                          ...
# 9883    Switzerland Â» Lago Maggiore Â» Riazzino                         1116
# 9884               Germany Â» Hamburg Â» HAMBURG                           94
# 9885     Germany Â» Nordrhein-Westfalen Â» Wesel                          354
# 9886                       Italy Â» Dormelletto                           266
# 9887        Switzerland Â» Brienzersee Â» Brienz                          194
#
# [9888 rows x 10 columns]

# %%
#Create column header for Currency from Price column
data_df['Currency'] = data_df['Price'].str[:3]
data_df.head()
# Out:
#        Price            Boat Type          Manufacturer                 Type  \
# 0   CHF 3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1   EUR 3490  Center console boat     Terhi power boats  new boat from stock
# 2   CHF 3770           Sport Boat    Marine power boats  new boat from stock
# 3  DKK 25900           Sport Boat    Pioner power boats  new boat from stock
# 4   EUR 3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#   Currency
# 0      CHF
# 1      EUR
# 2      CHF
# 3      DKK
# 4      EUR

# %%
#Remove Currency prefix from Price column
data_df['Price'] = data_df['Price'].str.slice(3)
data_df.head()
# Out:
#     Price            Boat Type          Manufacturer                 Type  \
# 0    3337          Motor Yacht  Rigiflex power boats  new boat from stock
# 1    3490  Center console boat     Terhi power boats  new boat from stock
# 2    3770           Sport Boat    Marine power boats  new boat from stock
# 3   25900           Sport Boat    Pioner power boats  new boat from stock
# 4    3399         Fishing Boat    Linder power boats  new boat from stock
#
#    Year Built  Length  Width       Material  \
# 0        2017    4.00   1.90            NaN
# 1        2020    4.00   1.50  Thermoplastic
# 2           0    3.69   1.42      Aluminium
# 3        2020    3.00   1.00            NaN
# 4        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#   Currency
# 0      CHF
# 1      EUR
# 2      CHF
# 3      DKK
# 4      EUR

# %%
#Reorder the dataframe so that Currency is listed first
reorder_df = data_df[['Currency', 'Price', 'Boat Type', 'Manufacturer','Type','Year Built','Length','Width','Material',
                      'Location','Number of views last 7 days']]
reorder_df.head()
# Out:
#   Currency   Price            Boat Type          Manufacturer  \
# 0      CHF    3337          Motor Yacht  Rigiflex power boats
# 1      EUR    3490  Center console boat     Terhi power boats
# 2      CHF    3770           Sport Boat    Marine power boats
# 3      DKK   25900           Sport Boat    Pioner power boats
# 4      EUR    3399         Fishing Boat    Linder power boats
#
#                   Type  Year Built  Length  Width       Material  \
# 0  new boat from stock        2017    4.00   1.90            NaN
# 1  new boat from stock        2020    4.00   1.50  Thermoplastic
# 2  new boat from stock           0    3.69   1.42      Aluminium
# 3  new boat from stock        2020    3.00   1.00            NaN
# 4  new boat from stock        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58

# %%
#Check the currencies listed.
#Note that Â£ might be considered GBP 
reorder_df['Currency'].value_counts()
# Out:
# EUR    8430
# CHF     980
# Â£      298
# DKK     180
# Name: Currency, dtype: int64

# %%
#reorder_df['date_time'] = pd.to_datetime('now')
#reorder_df.head()

# %%
#reorder_df.drop(['date_time'])
#reorder_df.head()

# %%
reorder_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Currency                     9888 non-null   object
#  1   Price                        9888 non-null   object
#  2   Boat Type                    9888 non-null   object
#  3   Manufacturer                 8550 non-null   object
#  4   Type                         9882 non-null   object
#  5   Year Built                   9888 non-null   int64
#  6   Length                       9879 non-null   float64
#  7   Width                        9832 non-null   float64
#  8   Material                     8139 non-null   object
#  9   Location                     9852 non-null   object
#  10  Number of views last 7 days  9888 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 849.9+ KB

# %%
reorder_df.Price = reorder_df.Price.astype(float)
(print(reorder_df.dtypes))
# Out:
# Currency                        object
# Price                          float64
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                       int64
# Length                         float64
# Width                          float64
# Material                        object
# Location                        object
# Number of views last 7 days      int64
# dtype: object

# %%
#Use a date to reference the currency conversation rate
reorder_df['date'] = pd.Timestamp('2023-09-05')
reorder_df.head()
# Out:
#   Currency    Price            Boat Type          Manufacturer  \
# 0      CHF   3337.0          Motor Yacht  Rigiflex power boats
# 1      EUR   3490.0  Center console boat     Terhi power boats
# 2      CHF   3770.0           Sport Boat    Marine power boats
# 3      DKK  25900.0           Sport Boat    Pioner power boats
# 4      EUR   3399.0         Fishing Boat    Linder power boats
#
#                   Type  Year Built  Length  Width       Material  \
# 0  new boat from stock        2017    4.00   1.90            NaN
# 1  new boat from stock        2020    4.00   1.50  Thermoplastic
# 2  new boat from stock           0    3.69   1.42      Aluminium
# 3  new boat from stock        2020    3.00   1.00            NaN
# 4  new boat from stock        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#         date  price in EUR
# 0 2023-09-05       3503.85
# 1 2023-09-05       3490.00
# 2 2023-09-05       3958.50
# 3 2023-09-05       3367.00
# 4 2023-09-05       3399.00

# %%
#Currency conversion dataframe
cc = pd.DataFrame(
    {'from':['EUR','CHF','EUR','DKK','EUR','Â£'],'to':['CHF','EUR','DKK','EUR','Â£','EUR'],'rate':[.95,1.05,7.45,.13,1.00,1.00]},
    

)
cc
# Out:
#   from   to  rate
# 0  EUR  CHF  0.95
# 1  CHF  EUR  1.05
# 2  EUR  DKK  7.45
# 3  DKK  EUR  0.13
# 4  EUR   Â£  1.00
# 5   Â£  EUR  1.00

# %%
#Applying conversion to EUR:
reorder_df['price in EUR'] = reorder_df['Price']*reorder_df.merge(cc[cc.to=='EUR'].append({'from':'EUR','to':'EUR','rate':1},ignore_index=True),left_on='Currency',right_on='from',how='left')['rate']
reorder_df
# Out:
# C:\Users\justi\AppData\Local\Temp\ipykernel_588\3231562371.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reorder_df['price in EUR'] = reorder_df['Price']*reorder_df.merge(cc[cc.to=='EUR'].append({'from':'EUR','to':'EUR','rate':1},ignore_index=True),left_on='Currency',right_on='from',how='left')['rate']
#      Currency    Price            Boat Type           Manufacturer  \
# 0         CHF   3337.0          Motor Yacht   Rigiflex power boats
# 1         EUR   3490.0  Center console boat      Terhi power boats
# 2         CHF   3770.0           Sport Boat     Marine power boats
# 3         DKK  25900.0           Sport Boat     Pioner power boats
# 4         EUR   3399.0         Fishing Boat     Linder power boats
# ...       ...      ...                  ...                    ...
# 9883      CHF   4900.0           Sport Boat    Sea Ray power boats
# 9884      EUR   4516.0           Sport Boat                    NaN
# 9885      EUR   4499.0           Sport Boat  BlueCraft power boats
# 9886      EUR   4300.0         Pontoon Boat      Whaly power boats
# 9887      CHF   3780.0         Fishing Boat    DarekCo power boats
#
#                               Type  Year Built  Length  Width       Material  \
# 0              new boat from stock        2017    4.00   1.90            NaN
# 1              new boat from stock        2020    4.00   1.50  Thermoplastic
# 2              new boat from stock           0    3.69   1.42      Aluminium
# 3              new boat from stock        2020    3.00   1.00            NaN
# 4              new boat from stock        2019    3.55   1.46      Aluminium
# ...                            ...         ...     ...    ...            ...
# 9883            Used boat,Unleaded        1987    6.30   2.44            NaN
# 9884           new boat from stock           0    4.17   1.68            GRP
# 9885  new boat from stock,Unleaded        2020    4.40   1.80            GRP
# 9886           new boat from stock        2018    4.37   1.89            NaN
# 9887           new boat from stock        2019    3.60   1.60            GRP
#
#                                         Location  Number of views last 7 days  \
# 0         Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                       Germany Â» BÃ¶nningstedt                           75
# 2     Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                           Denmark Â» Svendborg                           64
# 4                  Germany Â» Bayern Â» MÃ¼nchen                           58
# ...                                          ...                          ...
# 9883    Switzerland Â» Lago Maggiore Â» Riazzino                         1116
# 9884               Germany Â» Hamburg Â» HAMBURG                           94
# 9885     Germany Â» Nordrhein-Westfalen Â» Wesel                          354
# 9886                       Italy Â» Dormelletto                           266
# 9887        Switzerland Â» Brienzersee Â» Brienz                          194
#
#            date  price in EUR
# 0    2023-09-05       3503.85
# 1    2023-09-05       3490.00
# 2    2023-09-05       3958.50
# 3    2023-09-05       3367.00
# 4    2023-09-05       3399.00
# ...         ...           ...
# 9883 2023-09-05       5145.00
# 9884 2023-09-05       4516.00
# 9885 2023-09-05       4499.00
# 9886 2023-09-05       4300.00
# 9887 2023-09-05       3969.00
#
# [9888 rows x 13 columns]

# %%
#Applying conversion to USD:
reorder_df['price in USD'] = reorder_df['price in EUR']*1.07
reorder_df.head()
# Out:
#   Currency    Price            Boat Type          Manufacturer  \
# 0      CHF   3337.0          Motor Yacht  Rigiflex power boats
# 1      EUR   3490.0  Center console boat     Terhi power boats
# 2      CHF   3770.0           Sport Boat    Marine power boats
# 3      DKK  25900.0           Sport Boat    Pioner power boats
# 4      EUR   3399.0         Fishing Boat    Linder power boats
#
#                   Type  Year Built  Length  Width       Material  \
# 0  new boat from stock        2017    4.00   1.90            NaN
# 1  new boat from stock        2020    4.00   1.50  Thermoplastic
# 2  new boat from stock           0    3.69   1.42      Aluminium
# 3  new boat from stock        2020    3.00   1.00            NaN
# 4  new boat from stock        2019    3.55   1.46      Aluminium
#
#                                      Location  Number of views last 7 days  \
# 0      Switzerland Â» Lake Geneva Â» VÃ©senaz                          226
# 1                    Germany Â» BÃ¶nningstedt                           75
# 2  Switzerland Â» Lake of Zurich Â» StÃ¤fa ZH                          124
# 3                        Denmark Â» Svendborg                           64
# 4               Germany Â» Bayern Â» MÃ¼nchen                           58
#
#         date  price in EUR  price in USD
# 0 2023-09-05       3503.85     3749.1195
# 1 2023-09-05       3490.00     3734.3000
# 2 2023-09-05       3958.50     4235.5950
# 3 2023-09-05       3367.00     3602.6900
# 4 2023-09-05       3399.00     3636.9300

# %%
#In general, to remove non-ascii characters, use str.encode with errors='ignore':
#Source: https://www.appsloveworld.com/pandas/100/21/remove-non-ascii-characters-from-string-columns-in-pandas#google_vignette

reorder_df['Location'] = reorder_df['Location'].str.encode('ascii', 'ignore').str.decode('ascii')
reorder_df.head()
# Out:
#   Currency    Price            Boat Type          Manufacturer  \
# 0      CHF   3337.0          Motor Yacht  Rigiflex power boats
# 1      EUR   3490.0  Center console boat     Terhi power boats
# 2      CHF   3770.0           Sport Boat    Marine power boats
# 3      DKK  25900.0           Sport Boat    Pioner power boats
# 4      EUR   3399.0         Fishing Boat    Linder power boats
#
#                   Type  Year Built  Length  Width       Material  \
# 0  new boat from stock        2017    4.00   1.90            NaN
# 1  new boat from stock        2020    4.00   1.50  Thermoplastic
# 2  new boat from stock           0    3.69   1.42      Aluminium
# 3  new boat from stock        2020    3.00   1.00            NaN
# 4  new boat from stock        2019    3.55   1.46      Aluminium
#
#                                Location  Number of views last 7 days  \
# 0      Switzerland  Lake Geneva  Vsenaz                          226
# 1                  Germany  Bnningstedt                           75
# 2  Switzerland  Lake of Zurich  Stfa ZH                          124
# 3                    Denmark  Svendborg                           64
# 4               Germany  Bayern  Mnchen                           58
#
#         date  price in EUR  price in USD
# 0 2023-09-05       3503.85     3749.1195
# 1 2023-09-05       3490.00     3734.3000
# 2 2023-09-05       3958.50     4235.5950
# 3 2023-09-05       3367.00     3602.6900
# 4 2023-09-05       3399.00     3636.9300

# %%
manu_count = len(pd.unique(reorder_df['Manufacturer']))
manu_count
# Out:
# 911
